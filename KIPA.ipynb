# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# %%
df = pd.read_excel('df.xlsx')
df.head()
# Out:
#       week     wPreis           Plz                full       date
# 0  2020-37 -37.519318  ['25', '24']  A2 -  geschreddert 2020-09-14
# 1  2020-39 -40.000000  ['25', '24']  A2 -  geschreddert 2020-09-28
# 2  2020-41 -34.853543  ['25', '24']  A2 -  geschreddert 2020-10-12
# 3  2020-42 -27.560202  ['25', '24']  A2 -  geschreddert 2020-10-19
# 4  2020-43 -31.937780  ['25', '24']  A2 -  geschreddert 2020-10-26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3379 entries, 0 to 3378
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   week    3379 non-null   object
#  1   wPreis  3379 non-null   float64
#  2   Plz     3379 non-null   object
#  3   full    3379 non-null   object
#  4   date    3379 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 132.1+ KB

# %%
len(df)
# Out:
# 3379

# %%
df['Plz'].unique()
# Out:
# array(["['25', '24']", "['26', '27', '28']", "['20', '21', '22', '23']",
#        "['29', '30', '31', '38', '39']",
#        "['10', '11', '12', '13', '14', '15', '16']", "['48', '49']",
#        "['1', '4', '6', '7', '8', '9']",
#        "['40', '41', '42', '44', '45', '46', '47']",
#        "['50', '51', '52', '53']",
#        "['80', '81', '82', '83', '84', '85', '93', '94']"], dtype=object)

# %%
df['full'].unique()
# Out:
# array(['A2 -  geschreddert', 'A1 & A2 -  geschreddert',
#        'A2 & A3 -  geschreddert', 'A3 -  geschreddert'], dtype=object)

# %%
TS1 = df[(df['Plz'] == "['25', '24']") & (df['full'] == 'A2 -  geschreddert')]
TS1.head()
# Out:
#       week     wPreis           Plz                full       date
# 0  2020-37 -37.519318  ['25', '24']  A2 -  geschreddert 2020-09-14
# 1  2020-39 -40.000000  ['25', '24']  A2 -  geschreddert 2020-09-28
# 2  2020-41 -34.853543  ['25', '24']  A2 -  geschreddert 2020-10-12
# 3  2020-42 -27.560202  ['25', '24']  A2 -  geschreddert 2020-10-19
# 4  2020-43 -31.937780  ['25', '24']  A2 -  geschreddert 2020-10-26

# %%
TS1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 0 to 153
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   week    154 non-null    object
#  1   wPreis  154 non-null    float64
#  2   Plz     154 non-null    object
#  3   full    154 non-null    object
#  4   date    154 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 7.2+ KB

# %%
TS2.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 TS2.info()
#
# NameError: name 'TS2' is not defined

# %%
TS3 = df[(df['Plz'] == "['48', '49']") & (df['full'] == 'A2 & A3 -  geschreddert')]
TS3.head()
# Out:
#          week     wPreis           Plz                     full       date
# 2004  2020-37 -29.244584  ['48', '49']  A2 & A3 -  geschreddert 2020-09-14
# 2005  2020-38 -27.878925  ['48', '49']  A2 & A3 -  geschreddert 2020-09-21
# 2006  2020-39 -25.077400  ['48', '49']  A2 & A3 -  geschreddert 2020-09-28
# 2007  2020-40 -25.663645  ['48', '49']  A2 & A3 -  geschreddert 2020-10-05
# 2008  2020-41 -24.004958  ['48', '49']  A2 & A3 -  geschreddert 2020-10-12

# %%
TS3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 2004 to 2153
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   week    150 non-null    object
#  1   wPreis  150 non-null    float64
#  2   Plz     150 non-null    object
#  3   full    150 non-null    object
#  4   date    150 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 7.0+ KB

# %%
TS4 = df[(df['Plz'] == "['26', '27', '28']") & (df['full'] == 'A3 -  geschreddert')]
TS4.head()
# Out:
#         week     wPreis                 Plz                full       date
# 464  2020-37 -28.311162  ['26', '27', '28']  A3 -  geschreddert 2020-09-14
# 465  2020-38 -31.281060  ['26', '27', '28']  A3 -  geschreddert 2020-09-21
# 466  2020-39 -32.255530  ['26', '27', '28']  A3 -  geschreddert 2020-09-28
# 467  2020-40 -28.939862  ['26', '27', '28']  A3 -  geschreddert 2020-10-05
# 468  2020-41 -30.470931  ['26', '27', '28']  A3 -  geschreddert 2020-10-12

# %%
TS4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153 entries, 464 to 616
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   week    153 non-null    object
#  1   wPreis  153 non-null    float64
#  2   Plz     153 non-null    object
#  3   full    153 non-null    object
#  4   date    153 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 7.2+ KB

# %% [markdown]
# Nilou: I'm going to work with these clusters:
# "['25', '24']"
# "['26', '27', '28']"
# "['20', '21', '22', '23']"
# So first I created my sub-data frames, and then plotted the time series for each product category.

# %%
plz_24_25 = df[df['Plz']=="['25', '24']"]
plz_24_25['full'].unique()
# Out:
# array(['A2 -  geschreddert', 'A1 & A2 -  geschreddert',
#        'A2 & A3 -  geschreddert'], dtype=object)

# %%
plz_24_25_A2 = plz_24_25[plz_24_25['full']== 'A2 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_24_25_A2['dif']= plz_24_25_A2.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_24_25_A2['dif'].value_counts()
# Out:
# dif
# 7 days     149
# 14 days      3
# 0 days       1
# Name: count, dtype: int64

# %%
plz_24_25_A1_A2 = plz_24_25[plz_24_25['full'] == 'A1 & A2 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_24_25_A1_A2['dif']= plz_24_25_A1_A2.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_24_25_A1_A2['dif'].value_counts()
# Out:
# dif
# 7 days     149
# 14 days      3
# 0 days       1
# Name: count, dtype: int64

# %%
plz_24_25_A2_A3 = plz_24_25[plz_24_25['full'] == 'A2 & A3 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_24_25_A2_A3['dif']= plz_24_25_A2_A3.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_24_25_A2_A3['dif'].value_counts()
# Out:
# dif
# 7 days     153
# 0 days       1
# 14 days      1
# Name: count, dtype: int64

# %% [markdown]
# ## Should we fill out the time gap? if yes, HOW?

# %%
fig = px.line(plz_24_25, x='date', y='wPreis', color='full', title='Weekly Prices for [25,24] by Category')
fig.show()

# %%
plz_26_27_28 = df[df['Plz']=="['26', '27', '28']"]
plz_26_27_28['full'].unique()
# Out:
# array(['A3 -  geschreddert', 'A2 & A3 -  geschreddert'], dtype=object)

# %%
plz_26_27_28_A3 = plz_26_27_28[plz_26_27_28['full']== 'A3 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_26_27_28_A3['dif']= plz_26_27_28_A3.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_26_27_28_A3['dif'].value_counts()
# Out:
# dif
# 7 days     148
# 14 days      2
# 0 days       1
# 21 days      1
# Name: count, dtype: int64

# %%
plz_26_27_28_A2_A3 = plz_26_27_28[plz_26_27_28['full']== 'A2 & A3 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_26_27_28_A2_A3['dif']= plz_26_27_28_A2_A3.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_26_27_28_A2_A3['dif'].value_counts()
# Out:
# dif
# 7 days     153
# 0 days       1
# 14 days      1
# Name: count, dtype: int64

# %%
fig = px.line(plz_26_27_28, x='date', y='wPreis', color='full', title='Weekly Prices for [26,27,28] by Category')
fig.show()

# %%
plz_20_21_22_23= df[df['Plz']=="['20', '21', '22', '23']"]
plz_20_21_22_23['full'].unique()
# Out:
# array(['A2 -  geschreddert', 'A1 & A2 -  geschreddert',
#        'A2 & A3 -  geschreddert'], dtype=object)

# %%
plz_20_21_22_23_A2 = plz_20_21_22_23[plz_20_21_22_23['full']== 'A2 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_20_21_22_23_A2['dif']= plz_20_21_22_23_A2.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_20_21_22_23_A2['dif'].value_counts()
# Out:
# dif
# 7 days    155
# Name: count, dtype: int64

# %%
plz_20_21_22_23_A1_A2 = plz_20_21_22_23[plz_20_21_22_23['full']== 'A1 & A2 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_20_21_22_23_A1_A2['dif']= plz_20_21_22_23_A1_A2.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_20_21_22_23_A1_A2['dif'].value_counts()
# Out:
# dif
# 7 days    155
# Name: count, dtype: int64

# %%
plz_20_21_22_23_A2_A3 = plz_20_21_22_23[plz_20_21_22_23['full']== 'A2 & A3 -  geschreddert']
pd.options.mode.chained_assignment = None
plz_20_21_22_23_A2_A3['dif']= plz_20_21_22_23_A2_A3.date.diff()
pd.options.mode.chained_assignment = 'warn'
plz_20_21_22_23_A2_A3['dif'].value_counts()
# Out:
# dif
# 7 days    155
# 0 days      1
# Name: count, dtype: int64

# %%
fig = px.line(plz_20_21_22_23, x='date', y='wPreis', color='full', title='Weekly Prices for [20,21,22,23] by Product Category')
fig.show()

# %% [markdown]
# SURAJ: CLUSTERS: "['10', '11', '12', '13', '14', '15', '16']", "['48', '49']"

# %%
TS5 = df[(df['Plz'] == "['10', '11', '12', '13', '14', '15', '16']")] 
TS5.head()
# Out:
#          week     wPreis                                         Plz  \
# 1710  2020-37 -15.633292  ['10', '11', '12', '13', '14', '15', '16']
# 1711  2020-38 -18.201015  ['10', '11', '12', '13', '14', '15', '16']
# 1712  2020-39  -1.195535  ['10', '11', '12', '13', '14', '15', '16']
# 1713  2020-40  -9.591911  ['10', '11', '12', '13', '14', '15', '16']
# 1714  2020-41  -7.336622  ['10', '11', '12', '13', '14', '15', '16']
#
#                          full       date
# 1710  A1 & A2 -  geschreddert 2020-09-14
# 1711  A1 & A2 -  geschreddert 2020-09-21
# 1712  A1 & A2 -  geschreddert 2020-09-28
# 1713  A1 & A2 -  geschreddert 2020-10-05
# 1714  A1 & A2 -  geschreddert 2020-10-12

# %%
TS5['full'].unique() #Only 1 unique category
# Out:
# array(['A1 & A2 -  geschreddert'], dtype=object)

# %%
fig = px.line(TS5, x='date', y='wPreis', color='full', title='Weekly Prices for [10, 11, 12, 13, 14, 15, 16] by Category')
fig.show()

# %%
TS6 = df[(df['Plz'] == "['48', '49']")]  
TS6.head()
# Out:
#          week     wPreis           Plz                full       date
# 1854  2020-37 -29.244584  ['48', '49']  A3 -  geschreddert 2020-09-14
# 1855  2020-38 -27.878925  ['48', '49']  A3 -  geschreddert 2020-09-21
# 1856  2020-39 -25.077400  ['48', '49']  A3 -  geschreddert 2020-09-28
# 1857  2020-40 -25.663645  ['48', '49']  A3 -  geschreddert 2020-10-05
# 1858  2020-41 -24.004958  ['48', '49']  A3 -  geschreddert 2020-10-12

# %%
TS6['full'].unique()
# Out:
# array(['A3 -  geschreddert', 'A2 & A3 -  geschreddert'], dtype=object)

# %%
fig = px.line(TS6, x='date', y='wPreis', color='full', title='Weekly Prices for [48, 49] by Category')
fig.show()

# %% [markdown]
# OIL

# %%
oil = pd.read_excel('Crude_oil.xlsx')
oil.head()
# Out:
#            Date   Open   High    Low  Close*  Adj Close**     Volume
# 0  Sep 11, 2023  87.40  89.64  86.71   88.52        88.52    974.662
# 1  Sep 04, 2023  86.06  88.08  85.02   87.51        87.51  1,325,196
# 2  Aug 28, 2023  80.15  86.06  79.34   85.55        85.55  1,619,479
# 3  Aug 21, 2023  81.43  82.47  77.59   79.83        79.83  1,542,148
# 4  Aug 14, 2023  83.09  83.20  78.95   81.25        81.25  1,269,633

# %% [markdown]
# When exploring correlations between weekly oil prices and the price of another commodity like waste, the "Close" or "Adj Close" price is often used.
#
# Close Price: The "Close" price represents the closing price of the commodity for a specific trading day. It is the last price at which a trade occurred before the market closed for that day. This is a commonly used price metric for historical price analysis.
#
# Adjusted Close Price (Adj Close): The "Adj Close" price accounts for events such as stock splits and dividend payments. It is often considered more accurate for long-term analysis because it adjusts for corporate actions that can affect the price. In the context of Crude Oil, if there are similar adjustments, the "Adj Close" can be a better choice for long-term correlations.

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         158 non-null    object
#  1   Open         158 non-null    float64
#  2   High         158 non-null    float64
#  3   Low          158 non-null    float64
#  4   Close*       158 non-null    float64
#  5   Adj Close**  158 non-null    float64
#  6   Volume       158 non-null    object
# dtypes: float64(5), object(2)
# memory usage: 8.8+ KB

# %%
oil["Date"] = pd.to_datetime(oil["Date"])

# %%
oil.sort_values(by='Date')
# Out:
#           Date   Open   High    Low  Close*  Adj Close**     Volume
# 157 2020-09-07  39.48  39.59  36.13   37.33        37.33  1,907,673
# 156 2020-09-14  37.32  41.49  36.82   41.11        41.11  1,430,611
# 155 2020-09-21  40.98  41.27  38.66   40.25        40.25  1,171,773
# 154 2020-09-28  40.07  40.80  36.63   37.05        37.05  1,781,188
# 153 2020-10-05  37.00  41.47  37.00   40.60        40.60  1,953,665
# ..         ...    ...    ...    ...     ...          ...        ...
# 4   2023-08-14  83.09  83.20  78.95   81.25        81.25  1,269,633
# 3   2023-08-21  81.43  82.47  77.59   79.83        79.83  1,542,148
# 2   2023-08-28  80.15  86.06  79.34   85.55        85.55  1,619,479
# 1   2023-09-04  86.06  88.08  85.02   87.51        87.51  1,325,196
# 0   2023-09-11  87.40  89.64  86.71   88.52        88.52    974.662
#
# [158 rows x 7 columns]

# %%
fig = px.line(oil, x='Date', y='Adj Close**', title='Weekly Adjusted Close Price for Crude Oil')
fig.show()

# %% [markdown]
# Combining oil and wPreis in one table for plotting

# %%
combined_df = pd.merge(TS6[['date', 'wPreis', 'full']], oil[['Date', 'Adj Close**']], left_on='date', right_on='Date', how='inner')

# You can drop the duplicate 'Date' column if needed
combined_df = combined_df.drop(columns='Date')

combined_df
# Out:
#           date     wPreis                     full  Adj Close**
# 0   2020-09-14 -29.244584       A3 -  geschreddert        41.11
# 1   2020-09-14 -29.244584  A2 & A3 -  geschreddert        41.11
# 2   2020-09-21 -27.878925       A3 -  geschreddert        40.25
# 3   2020-09-21 -27.878925  A2 & A3 -  geschreddert        40.25
# 4   2020-09-28 -25.077400       A3 -  geschreddert        37.05
# ..         ...        ...                      ...          ...
# 295 2023-08-21   4.426446  A2 & A3 -  geschreddert        79.83
# 296 2023-08-28   5.545975       A3 -  geschreddert        85.55
# 297 2023-08-28   5.545975  A2 & A3 -  geschreddert        85.55
# 298 2023-09-04   8.037723       A3 -  geschreddert        87.51
# 299 2023-09-04   7.739649  A2 & A3 -  geschreddert        87.51
#
# [300 rows x 4 columns]

# %%
fig = go.Figure()

# Add traces for 'wPreis' and 'Adj Close**'
fig.add_trace(go.Scatter(x=combined_df['date'], y=combined_df['wPreis'], mode='lines', name='wPreis'))
fig.add_trace(go.Scatter(x=combined_df['date'], y=combined_df['Adj Close**'], mode='lines', name='Adj Close**'))

# Customize the layout
fig.update_layout(
    title="Time Series Comparison",
    xaxis_title="Date",
    yaxis_title="Value",
    xaxis=dict(type='date'),
)

# Show the legend
fig.update_layout(showlegend=True)

# Display the plot
fig.show()

# %% [markdown]
# That plotted all values including both the categories of full. Trying to plot them separately:

# %%
# Get unique categories
categories = combined_df['full'].unique()

# Create a Plotly figure
fig = go.Figure()

# Loop through each category and add a trace for it
for category in categories:
    category_data = combined_df[combined_df['full'] == category]
    fig.add_trace(go.Scatter(x=category_data['date'], y=category_data['wPreis'], mode='lines', name=f'wPreis ({category})'))
    fig.add_trace(go.Scatter(x=category_data['date'], y=category_data['Adj Close**'], mode='lines', name=f'Adj Close** ({category})'))

# Customize the layout
fig.update_layout(
    title="Time Series Comparison by Category",
    xaxis_title="Date",
    yaxis_title="Value",
    xaxis=dict(type='date'),
)

# Show the legend
fig.update_layout(showlegend=True)

# Display the plot
fig.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a combined DataFrame named combined_df
correlation_matrix = combined_df[['wPreis', 'Adj Close**']].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
fig, axes = plt.subplots(len(categories), figsize=(8, 6 * len(categories)))

# Loop through each category and create a heatmap
for i, category in enumerate(categories):
    category_data = combined_df[combined_df['full'] == category]
    correlation_matrix = category_data[['wPreis', 'Adj Close**']].corr()
    
    ax = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, ax=axes[i])
    ax.set_title(f'Correlation Heatmap for {category}')
    
# Adjust layout spacing
plt.tight_layout()

# Show the subplots
plt.show()
